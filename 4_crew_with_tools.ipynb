# %%
from dotenv import load_dotenv
load_dotenv()

from crewai import LLM
import os

llm = LLM(
    model="gemini/gemini-3.6-flash",
    api_key=os.getenv("GEMINI_API_KEY"),
)

# %%
from crewai import Agent, Task, Crew
from crewai_tools import SerperDevTool

research_agent = Agent(
    role="Research Specialist",
    goal="Research interesting facts about the topic: {topic}",
    backstory="You are an expert at finding relevant and factual data.",
    tools = [SerperDevTool()],
    verbose=True,
    llm=llm
)

writer_agent = Agent(
    role="Creative Writer",
    goal="Write a short blog summary using the research",
    backstory="You are skilled at writing engaging summaries based on provided content.",
    llm=llm,
    verbose=True,
)

# %%
task1 = Task(
    description="Find 3-5 interesting and recent facts about {topic} as of year 2026.",
    expected_output="A bullet list of 3-5 facts",
    agent=research_agent,
)

task2 = Task(
    description="Write a 100-word blog post summary about {topic} using the facts from the research.",
    expected_output="A blog post summary",
    agent=writer_agent,
    context=[task1],
)

# %%
response = llm.call("Say hello.")
print(response)
# Out:
# Hello! How can I help you today?

# %%
crew = Crew(
    agents=[research_agent, writer_agent],
    tasks=[task1, task2],
    verbose = True,
)

result = await crew.kickoff_async(
    inputs={"topic": "The future of electrical vehicles"}
)

print(result)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: c06ba7df-93bc-4b1e-8a8a-4aecc0c11147                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Find 3-5 interesting and recent facts about The future of electrical vehicles as of year 2026.           │
# │  ID: c920097c-ea22-44fa-a460-c8b0e973492c                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Task: Find 3-5 interesting and recent facts about The future of electrical vehicles as of year 2026.           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────── 🔧 Tool Execution Started (#1) ─────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool: search_the_internet_with_serper                                                                          │
# │  Args: {'search_query': 'electric vehicles future trends 2026 facts statistics'}                                │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Tool search_the_internet_with_serper executed with result: {'searchParameters': {'q': 'electric vehicles future trends 2026 facts statistics', 'type': 'search', 'num': 10, 'engine': 'google'}, 'organic': [{'title': 'Trends in electric cars – Global EV Outlook...
# ╭─────────────────────────────────────── ✅ Tool Execution Completed (#1) ────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool Completed                                                                                                 │
# │  Tool: search_the_internet_with_serper                                                                          │
# │  Output: {'searchParameters': {'q': 'electric vehicles future trends 2026 facts statistics', 'type': 'search',  │
# │  'num': 10, 'engine': 'google'}, 'organic': [{'title': 'Trends in electric cars – Global EV Outlook 2026 –      │
# │  Analysis', 'link': 'https://www.iea.org/reports/global-ev-outlook-2026/trends-in-electric-cars', 'snippet':    │
# │  'Across the region, electric car sales numbered 1 million more in 2025 than in the previous year, reaching a   │
# │  total of 4.2 million, or 28% of all new cars sold.', 'position': 1}, {'title': 'Electric Vehicle Outlook       │
# │  2026', 'link': 'https://about.bnef.com/insights/clean-transport/electric-vehicle-outlook/', 'snippet':         │
# │  'Passenger EV sales continue to rise in 2026, reaching 23.3 million globally, despite regulatory changes       │
# │  putting markets on divergent trajectories. This ...', 'position': 2}, {'title': "What's driving the adoption   │
# │  of EVs? Our latest report shows global ...", 'link':                                                           │
# │  'https://www.facebook.com/internationalenergyagency/videos/whats-driving-the-adoption-of-evs-our-latest-repor  │
# │  t-shows-global-electric-cars-s/1638559701154252/', 'snippet': '', 'position': 3}, {'title': 'Electric car      │
# │  statistics and data 2026: UK insights and global trends', 'link':                                              │
# │  'https://www.rac.co.uk/drive/electric-cars/choosing/electric-car-statistics-and-data/', 'snippet': '86,120     │
# │  new electric cars were registered in March 2026 - a new UK record. Electric cars make up 22.4% of the new car  │
# │  market so far in 2026, up ...', 'position': 4}, {'title': 'Electric Vehicles - United States | Market          │
# │  Forecast', 'link':                                                                                             │
# │  'https://www.statista.com/outlook/mmo/electric-vehicles/united-states/?srsltid=AfmBOorZZ9jGRH5ijlXkC3Lr_wblcV  │
# │  ZewIwq5XqFScydOSfptT22JCKN', 'snippet': 'The Electric Vehicles market in the United States is projected to     │
# │  reach a revenue of US$113.1bn in 2026. It is expected to show an annual growth rate (CAGR 2026 ...',           │
# │  'position': 5}, {'title': '2026 EV Market & Trends Report', 'link':                                            │
# │  'https://www.recurrentauto.com/research/new-ev-market-trends-report', 'snippet': 'The average EV retains 97%   │
# │  of its range after 3 years and 95% after 5 years, The average real-world range has climbed to 325 miles among  │
# │  2026 ...', 'position': 6}, {'title': 'EVs to hit almost a third of global new-vehicle sales in 2026 says       │
# │  IEA', 'link': 'https://www.youtube.com/watch?v=V9gt1McWB0U', 'snippet': 'Electric vehicles are on track to     │
# │  make up nearly one-third of all new vehicle sales worldwide in 2026, according to the latest forecast          │
# │  from\xa0...', 'position': 7}, {'title': '2026 Electric Vehicle Statistics', 'link':                            │
# │  'https://www.autoinsurance.com/research/electric-vehicle-statistics/', 'snippet': 'EV ownership worldwide has  │
# │  increased by an average of 61 percent year-over-year. EV sales have increased worldwide by 96 percent per      │
# │  year since', 'position': 8}, {'title': 'Global EV Outlook 2026 – Analysis', 'link':                            │
# │  'https://www.iea.org/reports/global-ev-outlook-2026', 'snippet': 'The Global EV Outlook is an annual           │
# │  publication that identifies and assesses recent developments in electric mobility across the globe.',          │
# │  'position': 9}, {'title': 'Electric Vehicle Market Size, Share and Trends 2026 to 2035', 'link':               │
# │  'https://www.precedenceresearch.com/electric-vehicle-market', 'snippet': 'The global electric vehicle market   │
# │  size was estimated at USD 988.70 billion in 2025 and is predicted to increase from USD 1,097.46 billion in     │
# │  2026 to ...', 'position': 10}], 'peopleAlsoAsk': [{'question': 'What are the expected EV trends in 2026?',     │
# │  'snippet': '', 'title': '', 'link': ''}, {'question': 'What is the most stolen EV?', 'snippet': '', 'title':   │
# │  '', 'link': ''}, {'question': 'Are electric vehicles worth it in 2026?', 'snippet': '', 'title': '', 'link':   │
# │  ''}, {'question': 'Are EVs declining in popularity?', 'snippet': '', 'title': '', 'link': ''}],                │
# │  'relatedSearches': [{'query': 'Electric vehicles future trends 2026 facts statistics graph'}, {'query':        │
# │  'Electric vehicles future trends 2026 facts statistics pdf'}, {'query': 'Electric vehicles future trends 2026  │
# │  facts statistics usa'}, {'query': 'Electric vehicles future trends 2026 facts statistics 2022'}, {'query':     │
# │  'Electric vehicle forecast 2030'}, {'query': 'Global EV Outlook 2026'}, {'query': 'Bnef electric vehicle       │
# │  outlook 2026'}, {'query': 'IEA Global EV Outlook 2026'}, {'query': 'Electric car sales 2026'}, {'query': 'IEA  │
# │  Global EV Outlook 2026 PDF'}], 'credits': 1}                                                                   │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────── 🔧 Tool Execution Started (#2) ─────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool: search_the_internet_with_serper                                                                          │
# │  Args: {'search_query': 'solid state battery commercial production EV 2026 2027'}                               │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Tool search_the_internet_with_serper executed with result: {'searchParameters': {'q': 'solid state battery commercial production EV 2026 2027', 'type': 'search', 'num': 10, 'engine': 'google'}, 'organic': [{'title': 'Will 2027 be the year of the solid-state e...
# ╭─────────────────────────────────────── ✅ Tool Execution Completed (#2) ────────────────────────────────────────╮
# │                                                                                                                 │
# │  Tool Completed                                                                                                 │
# │  Tool: search_the_internet_with_serper                                                                          │
# │  Output: {'searchParameters': {'q': 'solid state battery commercial production EV 2026 2027', 'type':           │
# │  'search', 'num': 10, 'engine': 'google'}, 'organic': [{'title': 'Will 2027 be the year of the solid-state      │
# │  electric vehicle battery?', 'link':                                                                            │
# │  'https://source.benchmarkminerals.com/article/will-2027-be-the-year-of-the-solid-state-electric-vehicle-batte  │
# │  ry', 'snippet': 'Several incumbent battery cell producers and automakers have committed to a demonstration of  │
# │  solid-state electric vehicles by 2027 with large-scale production ...', 'position': 1}, {'title': "CATL        │
# │  chief: solid-state batteries at 'level 4 of 9,' no leap until 2030", 'link':                                   │
# │  'https://electrek.co/2026/06/25/catl-solid-state-battery-level-4-2030/', 'snippet': 'BYD has confirmed it      │
# │  will begin putting all-solid-state batteries in vehicles in 2027, with large-scale mass production slated for  │
# │  2030.', 'position': 2}, {'title': '2026 Solid-State Battery Standard: Why 2027 Production Line Tell Us?',      │
# │  'link': 'https://www.youtube.com/watch?v=7pQuOI_tZRk', 'snippet': '2026 solid-state battery standard points    │
# │  to 2027 production lines instead of 2026 cars. Learn how standards, yield, cost, and manufacturing\xa0...',    │
# │  'position': 3}, {'title': 'Chinese Announcement on Solid State Batteries to Enter Mass Production in 2026',    │
# │  'link':                                                                                                        │
# │  'https://www.f150lightningforum.com/forum/threads/chinese-announcement-on-solid-state-batteries-to-enter-mass  │
# │  -production-in-2026.36252/', 'snippet': '', 'position': 4}, {'title': 'EV Solid-State Battery Validation       │
# │  Accelerates in the U.S. and Europe, Mass Production ...', 'link':                                              │
# │  'https://www.reddit.com/r/electricvehicles/comments/1lnccad/ev_solidstate_battery_validation_accelerates_in/'  │
# │  , 'snippet': '', 'position': 5}, {'title': 'Range anxiety is dead: Massive solid-state battery breakthrough    │
# │  coming in 2026', 'link':                                                                                       │
# │  'https://www.resetera.com/threads/range-anxiety-is-dead-massive-solid-state-battery-breakthrough-coming-in-20  │
# │  26.1363921/', 'snippet': '', 'position': 6}, {'title': 'Solid-State Batteries 2026: How the Technology Is      │
# │  Finally Reaching ...', 'link': 'https://to7motor.com/solid-state-batteries-2026-commercial-reality',           │
# │  'snippet': 'After decades of research, solid-state battery technology is entering real-world production in     │
# │  2026, with major manufacturers racing to ...', 'position': 7}, {'title': 'The industry reality in 2026         │
# │  suggests that the timeline for mass adoption ...', 'link':                                                     │
# │  'https://www.facebook.com/torquenews/posts/the-industry-reality-in-2026-suggests-that-the-timeline-for-mass-a  │
# │  doption-of-sol/1370556301756683/', 'snippet': 'Industry experts expect the first solid- state battery-powered  │
# │  EVs to enter the market between 2027 and 2030, contingent on production and cost ...', 'position': 8},         │
# │  {'title': 'Top 10 Solid-State Battery Companies 2026 & The Rise of Semi- ...', 'link':                         │
# │  'https://www.gsl-energy.com/top-10-solid-state-battery-companies-2026-the-rise-of-semi-solid-batteries-for-in  │
# │  dustrial-drones.html', 'snippet': 'Discover the top 10 solid-state battery companies in 2026 and why           │
# │  semi-solid batteries are leading industrial drone power systems with up to ...', 'position': 9}, {'title':     │
# │  'Solid-State EV Batteries Take a Step Closer to Production', 'link':                                           │
# │  'https://www.autoweek.com/news/a70258084/solid-state-ev-batteries-closer-to-production/', 'snippet':           │
# │  'Industry forecasts suggest that solid-state batteries could start appearing in production EVs in greater      │
# │  numbers between 2027 and 2030.', 'position': 10}], 'peopleAlsoAsk': [{'question': 'Will solid-state battery    │
# │  cars be available in 2026?', 'snippet': '', 'title': '', 'link': ''}, {'question': 'Is there a solid-state     │
# │  battery car expected in 2027?', 'snippet': '', 'title': '', 'link': ''}, {'question': 'What does Elon Musk     │
# │  say about solid-state batteries?', 'snippet': '', 'title': '', 'link': ''}, {'question': 'How soon will EVs    │
# │  have solid-state batteries?', 'snippet': '', 'title': '', 'link': ''}], 'relatedSearches': [{'query': 'Solid   │
# │  state battery commercial production ev 2026 2027 tesla'}, {'query': 'Solid state battery commercial            │
# │  production ev 2026 2027 release date'}, {'query': 'BYD solid-state battery 2027'}, {'query': 'Solid-state      │
# │  battery Toyota'}, {'query': 'Solid-state battery vs lithium-ion'}, {'query': 'Toyota solid-state battery       │
# │  release date'}, {'query': 'Mercedes solid-state battery'}, {'query': 'When will solid-state battery cars be    │
# │  available'}, {'query': 'When will solid-state batteries be in cars Tesla'}, {'query': 'Byd solid state         │
# │  battery range'}], 'credits': 1}                                                                                │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
