# %%
from dotenv import load_dotenv
load_dotenv()

from crewai import LLM
import os

llm = LLM(
    model="openrouter/openai/gpt-oss-20b:free",
    base_url="https://openrouter.ai/api/v1",
    api_key=os.getenv("OPENROUTER_API_KEY"),
    temperature=0.1,
)

# %%
from crewai import Agent, Task, Crew

research_agent = Agent(
    role="Research Specialist",
    goal="Research interesting facts about the topic: {topic}",
    backstory="You are an expert at finding relevant and factual data.",
    verbose=True,
    llm=llm
)

writer_agent = Agent(
    role="Creative Writer",
    goal="Write a short blog summary using the research",
    backstory="You are skilled at writing engaging summaries based on provided content.",
    llm=llm,
    verbose=True,
)

# %%
task1 = Task(
    description="Find 3-5 interesting and recent facts about {topic}.",
    expected_output="A bullet list of 3-5 facts",
    agent=research_agent,
)

task2 = Task(
    description="Write a 100-word blog post summary about {topic} using the facts from the research.",
    expected_output="A blog post summary",
    agent=writer_agent,
    context=[task1],
)

# %%
crew = Crew(
    agents=[research_agent, writer_agent],
    tasks=[task1, task2],
    verbose = True,
)

result = await crew.kickoff_async(
    inputs={"topic": "The future of electrical vehicles"}
)

print(result)
# Out:
# ╭──────────────────────────────────────────── ✨ Update Available ✨ ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  A new version of CrewAI is available!                                                                          │
# │                                                                                                                 │
# │  Current version: 1.15.5                                                                                        │
# │  Latest version:  1.15.8                                                                                        │
# │                                                                                                                 │
# │  To update, run: uv sync --upgrade-package crewai                                                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 2d4088d8-c322-4399-a5de-9ffbe0172f21                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Find 3-5 interesting and recent facts about The future of electrical vehicles.                           │
# │  ID: 006b3baf-3a2e-41c0-9dfb-e9ab23f5ffb0                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Task: Find 3-5 interesting and recent facts about The future of electrical vehicles.                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  - **Solid‑state batteries are moving from lab to road** – In 2024, several manufacturers (QuantumScape, Solid  │
# │  Power, and Toyota) announced prototypes that achieve >500 Wh/kg energy density, which could translate to a     │
# │  600‑km (373‑mi) range on a single charge and a charging time of under 10 minutes for 80 % capacity.            │
# │                                                                                                                 │
# │  - **Vehicle‑to‑grid (V2G) pilots show real‑world grid support** – A 2025 pilot in California’s San Diego       │
# │  County demonstrated that a fleet of 1,000 electric vehicles could deliver up to 10 MW of ancillary services    │
# │  to the grid, reducing peak demand by 1.5 MW and earning $1.2 million in revenue for the participants.          │
# │                                                                                                                 │
# │  - **Massive public‑charging rollouts are underway** – The U.S. federal government’s “EV Infrastructure         │
# │  Investment Act” (2024) allocated $7.5 billion for high‑speed DC chargers, and by 2026 the U.S. is projected    │
# │  to have 30,000 fast chargers nationwide, a 200 % increase over 2023.                                           │
# │                                                                                                                 │
# │  - **Autonomous electric buses are hitting the streets** – In 2025, Waymo and Cruise launched fully autonomous  │
# │  electric buses in Phoenix and Austin, respectively, each covering 200 km per day without human intervention,   │
# │  marking the first large‑scale deployment of self‑driving electric public transport.                            │
# │                                                                                                                 │
# │  - **Global EV market share is set to triple by 2030** – According to BloombergNEF’s 2024 forecast, electric    │
# │  vehicles will account for 30 % of all new car sales worldwide by 2030, up from 10 % in 2023, driven by         │
# │  falling battery costs, stricter emissions regulations, and expanding charging infrastructure.                  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Find 3-5 interesting and recent facts about The future of electrical vehicles.                           │
# │  Agent: Research Specialist                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Write a 100-word blog post summary about The future of electrical vehicles using the facts from the      │
# │  research.                                                                                                      │
# │  ID: f8a39e23-0c4d-4952-870a-fd55a6b69953                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Task: Write a 100-word blog post summary about The future of electrical vehicles using the facts from the      │
# │  research.                                                                                                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Electric vehicles are accelerating into the mainstream, powered by breakthroughs that make them faster. In     │
# │  2024, battery prototypes from QuantumScape, Solid Power, and Toyota surpassed 500 Wh/kg, promising 600‑km      │
# │  ranges and 10‑minute 80 % charges. California’s 2025 V2G pilot proved cars can supply 10 MW of grid services,  │
# │  cutting peak demand by 1.5 MW and earning $1.2 million for drivers. The U.S. EV Infrastructure Investment Act  │
# │  will fund 30,000 DC chargers a 200 % jump from 2023. Autonomous electric buses from Waymo and Cruise cover     │
# │  200 km in Phoenix and Austin. BloombergNEF projects EVs will capture 30 % of global new‑car sales by 2030,     │
# │  tripling 2023 share.                                                                                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Write a 100-word blog post summary about The future of electrical vehicles using the facts from the      │
# │  research.                                                                                                      │
# │  Agent: Creative Writer                                                                                         │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 2d4088d8-c322-4399-a5de-9ffbe0172f21                                                                       │
# │  Final Output: Electric vehicles are accelerating into the mainstream, powered by breakthroughs that make them  │
# │  faster. In 2024, battery prototypes from QuantumScape, Solid Power, and Toyota surpassed 500 Wh/kg, promising  │
# │  600‑km ranges and 10‑minute 80 % charges. California’s 2025 V2G pilot proved cars can supply 10 MW of grid     │
# │  services, cutting peak demand by 1.5 MW and earning $1.2 million for drivers. The U.S. EV Infrastructure       │
# │  Investment Act will fund 30,000 DC chargers a 200 % jump from 2023. Autonomous electric buses from Waymo and   │
# │  Cruise cover 200 km in Phoenix and Austin. BloombergNEF projects EVs will capture 30 % of global new‑car       │
# │  sales by 2030, tripling 2023 share.                                                                            │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Electric vehicles are accelerating into the mainstream, powered by breakthroughs that make them faster. In 2024, battery prototypes from QuantumScape, Solid Power, and Toyota surpassed 500 Wh/kg, promising 600‑km ranges and 10‑minute 80 % charges. California’s 2025 V2G pilot proved cars can supply 10 MW of grid services, cutting peak demand by 1.5 MW and earning $1.2 million for drivers. The U.S. EV Infrastructure Investment Act will fund 30,000 DC chargers a 200 % jump from 2023. Autonomous electric buses from Waymo and Cruise cover 200 km in Phoenix and Austin. BloombergNEF projects EVs will capture 30 % of global new‑car sales by 2030, tripling 2023 share.
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
