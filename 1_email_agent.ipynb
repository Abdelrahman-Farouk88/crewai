# %%
from dotenv import load_dotenv
import os

load_dotenv()
OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")

# %%
from crewai import LLM

# %%
llm = LLM(
    model="openrouter/openai/gpt-oss-20b:free",
    base_url="https://openrouter.ai/api/v1",
    api_key=os.getenv("OPENROUTER_API_KEY"),
    temperature=0.1,
)
response = llm.call("Who invented transcendental meditation?")
print(response)
# Out:
# **Transcendental Meditation (TM) was invented by Maharishi Mahesh Yogi.**
#
# - **Who he was:** Maharishi Mahesh Yogi (1918 – 2008) was a Hindu spiritual teacher and guru from India.
# - **When and how:** He developed the TM technique in the early 1950s, formalizing it in 1955 as a simple, silent mantra‑based meditation that could be practiced by anyone, regardless of religion or background.
# - **Key points of the technique:**
#   - Each practitioner is given a personal mantra by a certified teacher.
#   - The mantra is silently repeated for 20 minutes, twice a day.
#   - The practice is designed to allow the mind to settle into a state of “pure awareness” or transcendence.
#
# - **Impact:** TM spread worldwide, gaining popularity in the 1960s and 1970s (notably among the Beatles, Jimi Hendrix, and many other public figures). It has since been studied in scientific research and is taught by thousands of certified instructors globally.

# %%
from crewai import Agent, Task, Crew

email_assistant = Agent(
    role="Email Assistant Agent",
    goal="Improve emails and make them sound professional and clear",
    backstory="A highly experienced communication expert skilled in professional email writing",
    verbose=True,
    llm=llm
)

# %%
original_email = """
hey team, just wanted to tell u that the demo is kind of ready, but there's still stuff left.
Maybe we can show what we have and say rest is WIP.
Let me know what u think. thanks
"""

# %%
email_task = Task(
    description=f"""
Take the following rough email and rewrite it into a professional and polished version.

Expand abbreviations.

Email:
{original_email}
""",
    agent=email_assistant,
    expected_output="A professional written email with proper formatting and content."
)

# %%
crew = Crew(
    agents = [email_assistant],
    tasks = [email_task],
    verbose=True
)

result = await crew.kickoff_async()
print(result)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 8ef1d59c-47b7-4860-8c2b-f9fd39f084c1                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name:                                                                                                          │
# │  Take the following rough email and rewrite it into a professional and polished version.                        │
# │                                                                                                                 │
# │  Expand abbreviations.                                                                                          │
# │                                                                                                                 │
# │  Email:                                                                                                         │
# │                                                                                                                 │
# │  hey team, just wanted to tell u that the demo is kind of ready, but there's still stuff left.                  │
# │  Maybe we can show what we have and say rest is WIP.                                                            │
# │  Let me know what u think. thanks                                                                               │
# │                                                                                                                 │
# │                                                                                                                 │
# │  ID: 83c5d5d9-cdb6-4240-ad47-b12a36f8dbc6                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Email Assistant Agent                                                                                   │
# │                                                                                                                 │
# │  Task:                                                                                                          │
# │  Take the following rough email and rewrite it into a professional and polished version.                        │
# │                                                                                                                 │
# │  Expand abbreviations.                                                                                          │
# │                                                                                                                 │
# │  Email:                                                                                                         │
# │                                                                                                                 │
# │  hey team, just wanted to tell u that the demo is kind of ready, but there's still stuff left.                  │
# │  Maybe we can show what we have and say rest is WIP.                                                            │
# │  Let me know what u think. thanks                                                                               │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by NewConnectionError("HTTPSConnection(host='telemetry.crewai.com', port=4319): Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it")) encountered while exporting span batch, retrying in 1.01s.
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Email Assistant Agent                                                                                   │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Subject: Update on the Upcoming Demonstration                                                                  │
# │                                                                                                                 │
# │  Dear Team,                                                                                                     │
# │                                                                                                                 │
# │  I hope this message finds you well.                                                                            │
# │                                                                                                                 │
# │  I wanted to let you know that the demonstration is largely ready for presentation. However, there are still a  │
# │  few components that remain in progress. We could showcase the current state of the demo and clearly indicate   │
# │  that the remaining parts are still a work in progress.                                                         │
# │                                                                                                                 │
# │  Please let me know your thoughts on this approach. I appreciate your feedback.                                 │
# │                                                                                                                 │
# │  Thank you and best regards,                                                                                    │
# │                                                                                                                 │
# │  [Your Name]                                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name:                                                                                                          │
# │  Take the following rough email and rewrite it into a professional and polished version.                        │
# │                                                                                                                 │
# │  Expand abbreviations.                                                                                          │
# │                                                                                                                 │
# │  Email:                                                                                                         │
# │                                                                                                                 │
# │  hey team, just wanted to tell u that the demo is kind of ready, but there's still stuff left.                  │
# │  Maybe we can show what we have and say rest is WIP.                                                            │
# │  Let me know what u think. thanks                                                                               │
# │                                                                                                                 │
# │                                                                                                                 │
# │  Agent: Email Assistant Agent                                                                                   │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 8ef1d59c-47b7-4860-8c2b-f9fd39f084c1                                                                       │
# │  Final Output: Subject: Update on the Upcoming Demonstration                                                    │
# │                                                                                                                 │
# │  Dear Team,                                                                                                     │
# │                                                                                                                 │
# │  I hope this message finds you well.                                                                            │
# │                                                                                                                 │
# │  I wanted to let you know that the demonstration is largely ready for presentation. However, there are still a  │
# │  few components that remain in progress. We could showcase the current state of the demo and clearly indicate   │
# │  that the remaining parts are still a work in progress.                                                         │
# │                                                                                                                 │
# │  Please let me know your thoughts on this approach. I appreciate your feedback.                                 │
# │                                                                                                                 │
# │  Thank you and best regards,                                                                                    │
# │                                                                                                                 │
# │  [Your Name]                                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Subject: Update on the Upcoming Demonstration
#
# Dear Team,
#
# I hope this message finds you well.
#
# I wanted to let you know that the demonstration is largely ready for presentation. However, there are still a few components that remain in progress. We could showcase the current state of the demo and clearly indicate that the remaining parts are still a work in progress.
#
# Please let me know your thoughts on this approach. I appreciate your feedback.
#
# Thank you and best regards,
#
# [Your Name]
# ╭──────────────────────────────────────────────── Tracing Status ─────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing is disabled.                                                                                     │
# │                                                                                                                 │
# │  To enable tracing, do any one of these:                                                                        │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by NewConnectionError("HTTPSConnection(host='telemetry.crewai.com', port=4319): Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it")) encountered while exporting span batch, retrying in 2.37s.
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by NewConnectionError("HTTPSConnection(host='telemetry.crewai.com', port=4319): Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it")) encountered while exporting span batch, retrying in 4.15s.
# ERROR:opentelemetry.exporter.otlp.proto.http.trace_exporter:Failed to export span batch due to timeout, max retries or shutdown.
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by NewConnectionError("HTTPSConnection(host='telemetry.crewai.com', port=4319): Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it")) encountered while exporting span batch, retrying in 1.03s.
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by NewConnectionError("HTTPSConnection(host='telemetry.crewai.com', port=4319): Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it")) encountered while exporting span batch, retrying in 2.09s.
# WARNING:opentelemetry.exporter.otlp.proto.http.trace_exporter:Transient error HTTPSConnectionPool(host='telemetry.crewai.com', port=4319): Max retries exceeded with url: /v1/traces (Caused by NewConnectionError("HTTPSConnection(host='telemetry.crewai.com', port=4319): Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it")) encountered while exporting span batch, retrying in 4.34s.
# ERROR:opentelemetry.exporter.otlp.proto.http.trace_exporter:Failed to export span batch due to timeout, max retries or shutdown.

# %%
f
